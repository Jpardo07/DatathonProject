# %%
import pandas as pd
import numpy as np
import re

# %%
df_categories = pd.read_csv("products_categories.csv", sep=",", encoding='latin-1')

# %%
df_categories.head(40)
# Out:
#                                                   sku  \
# 0                                        00.01.10.014
# 1                                   00.071697.000.000
# 2                                              000133
# 3                                              000147
# 4                                              000148
# 5                                              000200
# 6                                              000203
# 7                                              000206
# 8                                              000210
# 9                                              000211
# 10                                             000235
# 11                                             000300
# 12                                             000313
# 13                                             000471
# 14                                             000543
# 15                                             000556
# 16                                            0005610
# 17                                     00065357300200
# 18                                            0007070
# 19                                     000910.Ballena
# 20                                     000910.Caracol
# 21                                       000910.Pulpo
# 22                                             000945
# 23                                             001003
# 24                                             001261
# 25                                             001262
# 26                                             001263
# 27                                             001264
# 28                                             001265
# 29                                             001267
# 30  001268,Salud,"Huesos, articulaciones y músculo...
# 31                                             001469
# 32                                             001492
# 33                                             001602
# 34                                          001657411
# 35                                             002150
# 36                                             002369
# 37                                             002370
# 38                                             002402
# 39                                      002426c013650
#
#                           cat1                                      cat2  \
# 0          Cosmética y Belleza                                  Corporal
# 1                     Infantil                                  Juguetes
# 2                     Infantil                          Higiene infantil
# 3   Higiene y cuidado personal                                    Facial
# 4          Cosmética y Belleza                                     Manos
# 5   Higiene y cuidado personal                                    Facial
# 6          Cosmética y Belleza                                  Corporal
# 7          Cosmética y Belleza                                  Corporal
# 8          Cosmética y Belleza                                  Corporal
# 9          Cosmética y Belleza                                  Corporal
# 10                    Infantil                                  Juguetes
# 11                    Infantil                          Higiene infantil
# 12                    Infantil                                 Lactancia
# 13                   Nutrición                       Nutrición Deportiva
# 14         Cosmética y Belleza                                    Facial
# 15                    Infantil                          Higiene infantil
# 16                    Infantil                                 Lactancia
# 17                    Infantil                Accesorios de alimentación
# 18                       Salud                              Aromaterapia
# 19                       Salud                                  Botiquín
# 20                       Salud                                  Botiquín
# 21                       Salud                                  Botiquín
# 22                       Salud  Problemas cardiovasculares y circulación
# 23                       Salud                     Vitaminas y Minerales
# 24                       Salud                     Descanso y relajación
# 25                       Salud                     Descanso y relajación
# 26                   Nutrición                           Pérdida de peso
# 27                   Nutrición                           Pérdida de peso
# 28                       Salud                     Vitaminas y Minerales
# 29                       Salud                    Trastornos digestivos
# 30                         NaN                                       NaN
# 31                 Veterinaria                                       NaN
# 32                       Salud                                    Óptica
# 33  Higiene y cuidado personal                                  Corporal
# 34  Higiene y cuidado personal                                      Pies
# 35                       Salud                     Vitaminas y Minerales
# 36                       Salud                                   Belleza
# 37                       Salud                     Descanso y relajación
# 38                       Salud                              Salud Sexual
# 39                       Salud                                    Óptica
#
#                              cat3
# 0                     Hidratación
# 1                      Mordedores
# 2         Canastillas y kits bebé
# 3   Desmaquillantes y limpiadores
# 4                  Crema de Manos
# 5                     Mascarillas
# 6                     Hidratación
# 7                     Hidratación
# 8                     Hidratación
# 9                     Hidratación
# 10                      Sonajeros
# 11        Canastillas y kits bebé
# 12       Accesorios de extracción
# 13                      Proteínas
# 14                       Ampollas
# 15        Canastillas y kits bebé
# 16            Discos de Lactancia
# 17      Esterilización y limpieza
# 18             Aceites esenciales
# 19                    Termómetros
# 20                    Termómetros
# 21                    Termómetros
# 22                     Colesterol
# 23                    Suplementos
# 24           Nerviosismo y estrés
# 25                            NaN
# 26                       Drenajes
# 27                       Drenajes
# 28                    Suplementos
# 29   Flora intestinal y digestión
# 30                            NaN
# 31                            NaN
# 32              Líquido lentillas
# 33                          Geles
# 34                Limas y durezas
# 35                    Suplementos
# 36                 Cabello | Uñas
# 37                            NaN
# 38                 Falta de Deseo
# 39              Líquido lentillas

# %%
#######################3

# %%
# df_categories[df_categories["cat1"].isna()]

# %%
df_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11159 entries, 0 to 11158
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sku     11159 non-null  object
#  1   cat1    10741 non-null  object
#  2   cat2    10721 non-null  object
#  3   cat3    10441 non-null  object
# dtypes: object(4)
# memory usage: 348.8+ KB

# %%
categories_na = df_categories[df_categories["cat1"].isna()]

# %%
categories_na
# Out:
#                                                      sku cat1 cat2 cat3
# 30     001268,Salud,"Huesos, articulaciones y músculo...  NaN  NaN  NaN
# 44     002655,Salud,Botiquín,"Apósitos, tiritas y gasas"  NaN  NaN  NaN
# 49     002870,Salud,"Huesos, articulaciones y músculo...  NaN  NaN  NaN
# 50     002872,Salud,"Huesos, articulaciones y músculo...  NaN  NaN  NaN
# 51     002873,Salud,"Huesos, articulaciones y músculo...  NaN  NaN  NaN
# ...                                                  ...  ...  ...  ...
# 10895  WJW158100,Salud,"Huesos, articulaciones y músc...  NaN  NaN  NaN
# 10915  WJW201100,Salud,"Huesos, articulaciones y músc...  NaN  NaN  NaN
# 10922  WJW236101,Nutrición,Alimentos,"Cremas, salsas ...  NaN  NaN  NaN
# 10957  ZAM01-15664,Salud,"Huesos, articulaciones y mú...  NaN  NaN  NaN
# 11082  ZMCOLMAV,Salud,"Huesos, articulaciones y múscu...  NaN  NaN  NaN
#
# [418 rows x 4 columns]

# %%
categories_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 30 to 11082
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sku     418 non-null    object
#  1   cat1    0 non-null      object
#  2   cat2    0 non-null      object
#  3   cat3    0 non-null      object
# dtypes: object(4)
# memory usage: 16.3+ KB

# %%
categories_sep = categories_na["sku"].str.split(",", expand=True)

# %%
categories_sep = categories_sep.rename(columns={0: "sku", 1: "cat1"})

# %%
categories_sep["cat2,3"] = categories_sep[[2,3,4]].apply(", ".join, axis=1)

# %%
categories_sep = categories_sep.drop(labels=[2,3,4], axis=1)

# %%
categories_sep.head()
# Out:
#        sku   cat1                                          cat2,3
# 30  001268  Salud  "Huesos,  articulaciones y músculos", Colágeno
# 44  002655  Salud          Botiquín, "Apósitos,  tiritas y gasas"
# 49  002870  Salud  "Huesos,  articulaciones y músculos", Colágeno
# 50  002872  Salud  "Huesos,  articulaciones y músculos", Colágeno
# 51  002873  Salud  "Huesos,  articulaciones y músculos", Colágeno

# %%
categories_sep_2_3 = categories_sep["cat2,3"].str.split('"', expand=True)

# %%
categories_sep_2_3 = categories_sep_2_3.rename(columns={0: "cat2", 1: "cat3"})

# %%
categories_sep_2_3
# Out:
#               cat2                                cat3  \
# 30                  Huesos,  articulaciones y músculos
# 44      Botiquín,           Apósitos,  tiritas y gasas
# 49                  Huesos,  articulaciones y músculos
# 50                  Huesos,  articulaciones y músculos
# 51                  Huesos,  articulaciones y músculos
# ...            ...                                 ...
# 10895               Huesos,  articulaciones y músculos
# 10915               Huesos,  articulaciones y músculos
# 10922  Alimentos,            Cremas,  salsas y siropes
# 10957               Huesos,  articulaciones y músculos
# 11082               Huesos,  articulaciones y músculos
#
#                              2
# 30                  , Colágeno
# 44
# 49                  , Colágeno
# 50                  , Colágeno
# 51                  , Colágeno
# ...                        ...
# 10895               , Colágeno
# 10915               , Colágeno
# 10922
# 10957  , Recuperación muscular
# 11082               , Colágeno
#
# [418 rows x 3 columns]

# %%
categories_sep_2_3
# Out:
#               cat2                                cat3  \
# 30                  Huesos,  articulaciones y músculos
# 44      Botiquín,           Apósitos,  tiritas y gasas
# 49                  Huesos,  articulaciones y músculos
# 50                  Huesos,  articulaciones y músculos
# 51                  Huesos,  articulaciones y músculos
# ...            ...                                 ...
# 10895               Huesos,  articulaciones y músculos
# 10915               Huesos,  articulaciones y músculos
# 10922  Alimentos,            Cremas,  salsas y siropes
# 10957               Huesos,  articulaciones y músculos
# 11082               Huesos,  articulaciones y músculos
#
#                              2
# 30                  , Colágeno
# 44
# 49                  , Colágeno
# 50                  , Colágeno
# 51                  , Colágeno
# ...                        ...
# 10895               , Colágeno
# 10915               , Colágeno
# 10922
# 10957  , Recuperación muscular
# 11082               , Colágeno
#
# [418 rows x 3 columns]

# %%
for pos, na in enumerate(categories_sep_2_3["cat2"]):
    if na == "":
        categories_sep_2_3["cat2"].iloc[pos] = categories_sep_2_3["cat3"].iloc[pos]
        categories_sep_2_3["cat3"].iloc[pos] = categories_sep_2_3[2].iloc[pos]

categories_sep_2_3.drop(columns=[2], inplace=True)

# %%
categories_sep_2_3["cat3"]=categories_sep_2_3["cat3"].str.replace("^[,]\s", "", regex=True)
categories_sep_2_3["cat2"]=categories_sep_2_3["cat2"].str.replace("[,]\s$", "", regex=True)

# %%
categories_sep_2_3
# Out:
#                                      cat2                        cat3
# 30     Huesos,  articulaciones y músculos                    Colágeno
# 44                               Botiquín  Apósitos,  tiritas y gasas
# 49     Huesos,  articulaciones y músculos                    Colágeno
# 50     Huesos,  articulaciones y músculos                    Colágeno
# 51     Huesos,  articulaciones y músculos                    Colágeno
# ...                                   ...                         ...
# 10895  Huesos,  articulaciones y músculos                    Colágeno
# 10915  Huesos,  articulaciones y músculos                    Colágeno
# 10922                           Alimentos   Cremas,  salsas y siropes
# 10957  Huesos,  articulaciones y músculos       Recuperación muscular
# 11082  Huesos,  articulaciones y músculos                    Colágeno
#
# [418 rows x 2 columns]

# %%
categories_sep_clean = pd.merge(categories_sep, categories_sep_2_3, left_index=True, right_index=True)
categories_sep_clean.drop(columns="cat2,3", inplace=True)

# %%
categories_sep_clean
# Out:
#                sku       cat1                                cat2  \
# 30          001268      Salud  Huesos,  articulaciones y músculos
# 44          002655      Salud                            Botiquín
# 49          002870      Salud  Huesos,  articulaciones y músculos
# 50          002872      Salud  Huesos,  articulaciones y músculos
# 51          002873      Salud  Huesos,  articulaciones y músculos
# ...            ...        ...                                 ...
# 10895    WJW158100      Salud  Huesos,  articulaciones y músculos
# 10915    WJW201100      Salud  Huesos,  articulaciones y músculos
# 10922    WJW236101  Nutrición                           Alimentos
# 10957  ZAM01-15664      Salud  Huesos,  articulaciones y músculos
# 11082     ZMCOLMAV      Salud  Huesos,  articulaciones y músculos
#
#                              cat3
# 30                       Colágeno
# 44     Apósitos,  tiritas y gasas
# 49                       Colágeno
# 50                       Colágeno
# 51                       Colágeno
# ...                           ...
# 10895                    Colágeno
# 10915                    Colágeno
# 10922   Cremas,  salsas y siropes
# 10957       Recuperación muscular
# 11082                    Colágeno
#
# [418 rows x 4 columns]

# %%
df_categories.drop(df_categories[df_categories["cat1"].isna()].index, inplace=True)

# %%
df_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10741 entries, 0 to 11158
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sku     10741 non-null  object
#  1   cat1    10741 non-null  object
#  2   cat2    10721 non-null  object
#  3   cat3    10441 non-null  object
# dtypes: object(4)
# memory usage: 419.6+ KB

# %%
# for i in df_categories["cat1"]:
#     if i is na:
#         df_categories["cat1"][i].drop(axis=0, inplace=True)

# %%
df_categories["cat1"].isna().sum()
# Out:
# 0

# %%
df_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10741 entries, 0 to 11158
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sku     10741 non-null  object
#  1   cat1    10741 non-null  object
#  2   cat2    10721 non-null  object
#  3   cat3    10441 non-null  object
# dtypes: object(4)
# memory usage: 419.6+ KB

# %%
df_categories_limpieza1 = pd.concat([df_categories, categories_sep_clean])

# %%
# df_categories_limpieza1 = df_categories.append(categories_sep_clean, ignore_index=True)

# %%
df_categories_limpieza1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11159 entries, 0 to 11082
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sku     11159 non-null  object
#  1   cat1    11159 non-null  object
#  2   cat2    11139 non-null  object
#  3   cat3    10859 non-null  object
# dtypes: object(4)
# memory usage: 435.9+ KB

# %%
df_categories_limpieza1[df_categories_limpieza1["cat2"].isna()]
# Out:
#                 sku         cat1 cat2 cat3
# 31           001469  Veterinaria  NaN  NaN
# 743   113159=575349  Veterinaria  NaN  NaN
# 8172         570052  Veterinaria  NaN  NaN
# 8173         570235  Veterinaria  NaN  NaN
# 8174         570237  Veterinaria  NaN  NaN
# 8180         571007  Veterinaria  NaN  NaN
# 8181         571008  Veterinaria  NaN  NaN
# 8182         571014  Veterinaria  NaN  NaN
# 8183         571017  Veterinaria  NaN  NaN
# 8184         571023  Veterinaria  NaN  NaN
# 8185         571024  Veterinaria  NaN  NaN
# 8186         578400  Veterinaria  NaN  NaN
# 8187         578401  Veterinaria  NaN  NaN
# 8188         578403  Veterinaria  NaN  NaN
# 8190         583685  Veterinaria  NaN  NaN
# 8191         583688  Veterinaria  NaN  NaN
# 8192         583689  Veterinaria  NaN  NaN
# 8193         583696  Veterinaria  NaN  NaN
# 8194         583700  Veterinaria  NaN  NaN
# 9835        MF10023  Veterinaria  NaN  NaN

# %%
df_categories["cat1"] = df_categories["cat1"].str.lower()
df_categories["cat2"] = df_categories["cat2"].str.lower()
df_categories["cat3"] = df_categories["cat3"].str.lower()

# %%
df_categories_limpieza1.to_csv("categories_limpieza1.csv")

# %%
# categories_na.to_csv("categories_na.csv")

# %%
# categories_na_df = pd.read_csv("categories_na.csv", sep=',')

# %%
# categories_na_df
