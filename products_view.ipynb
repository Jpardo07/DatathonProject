# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
products = pd.read_csv("Modificados - Atmira_Pharma_Visualization/products.csv")

# %%
products
# Out:
#        product_id           sku  \
# 0            7349        165774
# 1            7347        165776
# 2           50282        230154
# 3            7348        165775
# 4           24517        011905
# ...           ...           ...
# 27948       22432   433363.AZUL
# 27949       30090  10.22.12.256
# 27950       97587      PURO0113
# 27951        3693        211391
# 27952       51856        PT3603
#
#                                                     name    marca_value  \
# 0         Pañales CHELINO LOVE Talla3 4-10 KG 36unidades        Chelino
# 1        Pañales CHELINO LOVE Talla5 13-18 KG 30unidades        Chelino
# 2                           Pañales Pingo Maxi T4 40 uds          Pingo
# 3         Pañales CHELINO LOVE Talla4 9-15 KG 34unidades        Chelino
# 4                           Dodot Pañal T4 9-15Kg 30unds          Dodot
# ...                                                  ...            ...
# ...

# %%
products.shape
# Out:
# (27953, 7)

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27953 entries, 0 to 27952
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         27953 non-null  int64
#  1   sku                27953 non-null  object
#  2   name               27939 non-null  object
#  3   marca_value        27921 non-null  object
#  4   short_description  27930 non-null  object
#  5   analytic_category  24416 non-null  object
#  6   picture            27947 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ MB

# %%
products[products.duplicated()].shape
# Out:
# (0, 7)

# %% [markdown]
# ### id y sku

# %%
products['product_id'].value_counts()
# Out:
# 23299    4
# 2493     4
# 13134    4
# 2491     4
# 5573     4
#         ..
# 21041    1
# 24604    1
# 52213    1
# 70477    1
# 51856    1
# Name: product_id, Length: 23183, dtype: int64

# %%
products[products.duplicated(["product_id"])]
# Out:
#        product_id           sku  \
# 3067         5572        358838
# 3068         4629        358820
# 3097         5574        150402
# 3098         5573        357905
# 3269         5575        185501
# ...           ...           ...
# 27946       46420      42401068
# 27947       46414      42401568
# 27948       22432   433363.AZUL
# 27949       30090  10.22.12.256
# 27951        3693        211391
#
#                                                     name    marca_value  \
# 3067      Aceite Corporal de Calendula Bebe Weleda 200ml         Weleda
# 3068             Crema Facial Bebe Calendula Weleda 50ml         Weleda
# 3097   Champu y Gel de Ducha de Calendula Bebe Weleda...         Weleda
# 3098       Leche Corporal de Calendula Bebe Weleda 200ml         Weleda
# 3269               Baño de Crema de Calendula Bebe 200ml         Weleda
# ...                                                  ...            ...
# ...

# %%
sum(products["product_id"].value_counts() > 1)
# Out:
# 4334

# %%
sum(products["product_id"].value_counts() <= 1)
# Out:
# 18849

# %%
sum(products["sku"].value_counts() <= 1)
# Out:
# 18902

# %%
sum(products["sku"].value_counts() > 1)
# Out:
# 4314

# %%
sum(products["sku"].value_counts() > 1) & sum(products["product_id"].value_counts() > 1)
# Out:
# 4298

# %%
products[products["product_id"] == 2493]
# Out:
#        product_id     sku                                           name  \
# 2191         2493  152792            Crema Reafirmante Woman Isdin 150ml
# 7400         2493  152792          Velastina reafirmante pós-parto 150ml
# 23940        2493  152792        Woman Isdin reafirmante pós-parto 150ml
# 27508        2493  152792  Creme Isdin Woman reafirmante pós-parto 150ml
#
#       marca_value                                  short_description  \
# 2191        Isdin  <p>Esta crema está especialmente indicada para...
# 7400        Isdin  <p>Esta crema está especialmente indicada para...
# 23940       Isdin  <p>Esta crema está especialmente indicada para...
# 27508       Isdin  <p>Esta crema está especialmente indicada para...
#
#       analytic_category                                            picture
# 2191           Infantil  https://www.mifarma.es/media/catalog/product/2...
# 7400           Infantil  https://www.mifarma.es/media/catalog/product/2...
# ...

# %% [markdown]
# ### pictures

# %%
products["picture"].isna().sum()
# Out:
# 6

# %%
products["picture"].value_counts()
# Out:
# https://www.mifarma.es/media/catalog/product/1/5/159387_234444_.jpg     4
# https://www.mifarma.es/media/catalog/product/1/9/197950_.jpg            4
# https://www.mifarma.es/media/catalog/product/1/5/159078_.jpg            4
# https://www.mifarma.es/media/catalog/product/1/8/183286_.jpg            4
# https://www.mifarma.es/media/catalog/product/4/4/448478417040_.jpg      4
#                                                                        ..
# https://www.mifarma.es/media/catalog/product/8/0/802569.naranja_.jpg    1
# https://www.mifarma.es/media/catalog/product/1/8/180896_.jpg            1
# https://www.mifarma.es/media/catalog/product/b/c/bc875_.jpg             1
# https://www.mifarma.es/media/catalog/product/1/5/157168_.jpg            1
# https://www.mifarma.es/media/catalog/product/p/t/pt3603_.jpg            1
# Name: picture, Length: 23175, dtype: int64

# %%
products["picture"].tail()
# Out:
# 27948    https://www.mifarma.es/media/catalog/product/4...
# 27949    https://www.mifarma.es/media/catalog/product/1...
# 27950    https://www.mifarma.es/media/catalog/product/p...
# 27951    https://www.mifarma.es/media/catalog/product/2...
# 27952    https://www.mifarma.es/media/catalog/product/p...
# Name: picture, dtype: object

# %% [markdown]
# ### names

# %%
products[products["name"].isna()]
# Out:
#        product_id     sku name marca_value  \
# 18323         380  170696  NaN       Vichy
# 18324         647  203465  NaN       Avene
# 18326        3717  369702  NaN   Martiderm
# 18327        3721  154563  NaN   Martiderm
# 18331         645  356709  NaN       Avene
# 18332        1797  255620  NaN       Isdin
# 18334        3501  238436  NaN     Klorane
# 18337        3861  234790  NaN    Sesderma
# 18339        2671  194340  NaN      Uriage
# 18340        1730  159316  NaN       Isdin
# 18341        3947  160260  NaN   Neostrata
# 18350        1336  330669  NaN   Bepanthol
# 18351        2354  060095  NaN        Evax
# 18352        2524  310601  NaN       Goibi
#
#                                        short_description    analytic_category  \
# 18323  <p>Desodorante antitranspirante sin alcohol co...              Higiene
# 18324  <p>El Agua termal de Avène es un verdadero pri...  Cosmética y Belleza
# ...

# %%
products["name"].value_counts().head(10)
# Out:
# Avene Couvrance Compacto                                 4
# Medela Embudo Personal Fit                               3
# IAP Pharma Perfume mulher n º 150 ml                     3
# Medela Top de Extracción Fácil Sujetador Manos Libres    3
# Babé Stick Labial 4 Gramos                               2
# Gel Masaje Madagascar Sweetness Control 200ml            2
# Nivea Crema 150ml                                        2
# Gel Contorno de Ojos Sesderma Men 15ml                   2
# Babaria Crema Facial Antiarrugas Rosa Mosqueta 50ml      2
# Sebamed Champú Dermatológico Anticaspa                   2
# Name: name, dtype: int64

# %%
products[products.duplicated(["name"])]
# Out:
#        product_id                    sku  \
# 6159        35799              213000-x3
# 6417         4868       Phytocolor-PH963
# 7560         4490  sebamed.champu-372656
# 8557        74810               175341x2
# 9725        24277                 168460
# ...           ...                    ...
# 26078        3455                 179135
# 26569       39913             178408Azu3
# 26897       44255       MN12104U.Naranja
# 26924       71104          CB23263X.niña
# 27067        5012                 378406
#
#                                                     name    marca_value  \
# 6159   Epaplus Magnesio + Acido Hialuronico + Vitamin...       Epa-plus
# 6417                               Phytocolor Kit Color           Phyto
# 7560             Sebamed Champú Dermatológico Anticaspa         Sebamed
# 8557   Singuladerm XpertSun Perfection Natural SPF 50 5g    Singuladerm
# 9725               Crema Facial Malva Blanca Weleda 50ml         Weleda
# ...

# %% [markdown]
# ### marca

# %%
products["marca_value"].value_counts().head(50)
# Out:
# Suavinex          761
# Chicco            698
# Sesderma          474
# Isdin             461
# Nuk               405
# Apivita           372
# La Roche Posay    364
# Mam               350
# Soria Natural     348
# InterApothek      322
# Nuxe              311
# Beter             302
# Arkopharma        287
# Otras Marcas      287
# Canpol Babies     285
# Uriage            267
# Ziaja             263
# Vichy             259
# Th Pharma         252
# Tommee tippee     251
# Avene             245
# Avent             240
# Eucerin           239
# Bioderma          239
# Pranarom          222
# Sotya             222
# Sensilis          206
# Bell              203
# Lacer             197
# Solgar            192
# Be+               189
# Saro              187
# Nûby              185
# iap pharma        180
# Rene Furterer     178
# Klorane           178
# Weleda            172
# Caudalie          169
# Rilastil          167
# Babaria           167
# Mustela           166
# ...

# %%
products["marca_value"].isna().sum()
# Out:
# 32

# %%
products[products["marca_value"].isna()]
# Out:
#        product_id                            sku  \
# 622          9467                         162269
# 923          7105                         157899
# 1029         1031     SERV262253X2-262253-262253
# 4376         7108                         152810
# 4451          513         317171x2-317171-317171
# 5063         8852                       1401LAT2
# 5738        23899                          DUGIN
# 5863        23893                          DUPAG
# 5939        23884                        DUCAR01
# 7308         8851                       1401LAT3
# 9188        17205                          DUGAS
# 9820        33677                 CONFETTI.M.CIR
# 9992         8882                      125DEBLA4
# 10281        5862                    KIT153827x2
# 11338       17208                       DUDEPECO
# 11680        7103                         152811
# 12641       11609                          DUVIT
# 13094       78484                       152937.0
# ...

# %% [markdown]
# ### category

# %%
products["analytic_category"].value_counts()
# Out:
# Cosmética y Belleza    8336
# Higiene                5410
# Infantil               4901
# Herbolario             2801
# Nutrición              1600
# Ortopedia               572
# Vida Íntima             340
# Óptica                  244
# Perfumeria              165
# Veterinaria              47
# Name: analytic_category, dtype: int64

# %%
products["analytic_category"].unique()
# Out:
# array(['Infantil', nan, 'Cosmética y Belleza', 'Óptica', 'Higiene',
#        'Herbolario', 'Ortopedia', 'Nutrición', 'Vida Íntima',
#        'Veterinaria', 'Perfumeria'], dtype=object)

# %%
products["analytic_category"].isna().sum()
# Out:
# 3537

# %%
products[products["analytic_category"].isna()].head()
# Out:
#     product_id     sku                                               name  \
# 4        24517  011905                       Dodot Pañal T4 9-15Kg 30unds
# 5        11938  011896         Dodot Activity T3 De 4 A 10 Kg 56 Unidades
# 6        13109  011894              Dodot Pañal Sensitive T1 2-5Kg 30Unds
# 14       12051  013687  Dodot Sensitive Pañal Primeras Semanas T/0 Has...
# 31       13122  011907          Dodot Pañal Pack Semanal T/5 13-18kg 25ud
#
#    marca_value                                  short_description  \
# 4        Dodot  <p>¿Qué le pides a un pañal? ¿Absorción máxima...
# 5        Dodot  <p>Pañales que mantienen la piel del culito se...
# 6        Dodot  <p>Pañales para recién nacido que evitan la ir...
# 14       Dodot  <p>Pañales Dodot para una máxima absorción de ...
# 31       Dodot                      <p>Pañales pack semanal\n</p>
#
#    analytic_category                                            picture
# ...

# %%
products[products["short_description"].str.find("<strong>") > 1].head(10)
# Out:
#     product_id     sku                                               name  \
# 0         7349  165774     Pañales CHELINO LOVE Talla3 4-10 KG 36unidades
# 1         7347  165776    Pañales CHELINO LOVE Talla5 13-18 KG 30unidades
# 2        50282  230154                       Pañales Pingo Maxi T4 40 uds
# 3         7348  165775     Pañales CHELINO LOVE Talla4 9-15 KG 34unidades
# 7        60743  183816  Cumlaude Sunlaude Niños Ultrafluido Mineral SP...
# 8        50297  230130                       Pañales Pingo Midi T3 44 uds
# 11       33565  176748             Cumlaude Visilaude Gotas Oculares 10ml
# 12       65365   14507  Desodorante de Avena Roll On Instituto Español...
# 14       12051  013687  Dodot Sensitive Pañal Primeras Semanas T/0 Has...
# 15       43862  180156       Dodot Sensitive Pañal Recien Nacido T2 34uds
#
#           marca_value                                  short_description  \
# 0             Chelino  <p>Los pañales <strong>Chelino</strong>, que p...
# ...

# %%
products[(products["short_description"].str.find("<strong>") > 1) & (products["analytic_category"].isna())]
# Out:
#        product_id                sku  \
# 14          12051             013687
# 62          13104             011899
# 373          5429             002872
# 393          8079             165889
# 413          5424             002870
# ...           ...                ...
# 27575       95442               FRUS
# 27589       13104             011899
# 27636        7657           167925x2
# 27740        3970  SERV348549-348549
# 27769       49207              04028
#
#                                                     name  \
# 14     Dodot Sensitive Pañal Primeras Semanas T/0 Has...
# 62                           Dodot Pañal T2 3-6Kg 40Unds
# 373    Carbonato de magnesio 75 comprimidos Ana Maria...
# 393    Gynea Serelys Perimenopausia Menopausia Sofoco...
# 413    Magnesio Cloruro 147 Comprimidos Ana María La ...
# ...                                                  ...
# 27575                   Lubricante Frutopia Sandía 100ml
# ...

# %% [markdown]
# #### product_id - sku
# Varios duplicados. El número es diferente al de sku duplicados.
# #### name
# Hay algunos missings que se pueden sustituir tomando marca y descripción (son pocos).
#
# #### marca
# Intentar sacar missing (son pocos) por name y description.
# Visualización... Interesante ver cuánto se vende por cada marca y top productos más vendidos.
#
# #### description
# Importante... etiquetas como "<strong" nos pueden decir mucho para imputar variables faltantes...
# No lo veo útil para visualización. Se podría imputar quitando etiquetas html (regex?), pero no lo veo...
#
# #### category
# Hay 3537 nulos... se podría tirar un modelo con palabras para imputar?
#
# #### pict
# Link de las img no sirve. Está desactualizado. img guardadas en otro sitio?
# Ejemplo de una imagen de producto...https://d2csxpduxe849s.cloudfront.net/media/07EADC…ct%20High-79330F8C-1FDE-46EF-99CD8FACECA99C66.png
