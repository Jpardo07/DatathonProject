# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
products = pd.read_csv("products.csv")

# %%
products.head()
# Out:
#    product_id     sku                                             name  \
# 0        7349  165774   Pañales CHELINO LOVE Talla3 4-10 KG 36unidades
# 1        7347  165776  Pañales CHELINO LOVE Talla5 13-18 KG 30unidades
# 2       50282  230154                     Pañales Pingo Maxi T4 40 uds
# 3        7348  165775   Pañales CHELINO LOVE Talla4 9-15 KG 34unidades
# 4       24517  011905                     Dodot Pañal T4 9-15Kg 30unds
#
#   marca_value                                  short_description  \
# 0     Chelino  <p>Los pañales <strong>Chelino</strong>, que p...
# 1     Chelino  <p>Los pañales Chelino que presentan un novedo...
# 2       Pingo  <p>Pingo es el primer pañal ecológico con cuat...
# 3     Chelino  <p>Los pañales Chelino, que presentan un noved...
# 4       Dodot  <p>¿Qué le pides a un pañal? ¿Absorción máxima...
#
#   analytic_category                                            picture
# 0          Infantil  https://www.mifarma.es/media/catalog/product/1...
# ...

# %%
products.shape
# Out:
# (27953, 7)

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27953 entries, 0 to 27952
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         27953 non-null  int64
#  1   sku                27953 non-null  object
#  2   name               27939 non-null  object
#  3   marca_value        27921 non-null  object
#  4   short_description  27930 non-null  object
#  5   analytic_category  24416 non-null  object
#  6   picture            27947 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ MB

# %%
products[products.duplicated()].shape
# Out:
# (0, 7)

# %% [markdown]
# ### id y sku

# %%
products['product_id'].value_counts()[:3]
# Out:
# 7349     1
# 45310    1
# 45328    1
# Name: product_id, dtype: int64

# %%
products[products.duplicated(["product_id"])].head()
# Out:
#       product_id     sku                                               name  \
# 3067        5572  358838     Aceite Corporal de Calendula Bebe Weleda 200ml
# 3068        4629  358820            Crema Facial Bebe Calendula Weleda 50ml
# 3097        5574  150402  Champu y Gel de Ducha de Calendula Bebe Weleda...
# 3098        5573  357905      Leche Corporal de Calendula Bebe Weleda 200ml
# 3269        5575  185501              Baño de Crema de Calendula Bebe 200ml
#
#      marca_value                                  short_description  \
# 3067      Weleda  <p>Tratamiento protector para pieles sensibles...
# 3068      Weleda  <p>Crema facial para bebés rica en extracto de...
# 3097      Weleda  <p>Limpieza extra suave para cabello y piel de...
# 3098      Weleda  <p>Leche corporal indicada para el cuidado dia...
# 3269      Weleda  <p>Crema de caléndula ideal para los primeros ...
#
#      analytic_category                                            picture
# ...

# %%
products.drop_duplicates(subset="product_id", keep="first", inplace=True)

# %%
products[products.duplicated(["product_id"])].shape
# Out:
# (0, 7)

# %%
products.shape
# Out:
# (23183, 7)

# %%
products[products["product_id"]== 5572]
# Out:
#       product_id     sku                                     name marca_value  \
# 1806        5572  358838  Weleda Bebé Aceite de Caléndula 200 ml       Weleda
#
#                                       short_description analytic_category  \
# 1806  <p>Tratamiento protector para pieles sensibles...          Infantil
#
#                                                 picture
# 1806  https://www.mifarma.es/media/catalog/product/3...

# %%
sum(products["product_id"].value_counts() > 1)
# Out:
# 0

# %%
sum(products["product_id"].value_counts() == 1)
# Out:
# 23183

# %%
sum(products["sku"].value_counts() == 1)
# Out:
# 23173

# %%
sum(products["sku"].value_counts() > 1)
# Out:
# 5

# %%
products[products.duplicated(["sku"])]
# Out:
#        product_id                       sku  \
# 7452         7194     sebamed.champu-361303
# 11091         678                 a3-200181
# 11464        8337          Phytocolor-PH969
# 15308        9628  serv201939.232504-201939
# 25010        4525      308056.152223-152223
#
#                                                     name marca_value  \
# 7452      Sebamed Champú Dermatológico Anticaspa  500 ml     Sebamed
# 11091                Avene Couvrance Compacto Arena 10gr       Avene
# 11464  Phytocolor Kit Color 6AC Rubio Oscuro Caoba Co...       Phyto
# 15308                     Sebamed Aceite de Ducha 200 ml     Sebamed
# 25010                    Femíntim Adulto Gel íntimo Leti        Leti
#
#                                        short_description    analytic_category  \
# 7452   <p>Champú sin jabón anticaspa para el lavado d...                  NaN
# 11091  <p>Maquillaje compacto en crema para pieles se...  Cosmética y Belleza
# ...

# %%
products[products["sku"]== "a3-200181"]
# Out:
#        product_id        sku                                 name marca_value  \
# 6439         4194  a3-200181             Avene Couvrance Compacto       Avene
# 11091         678  a3-200181  Avene Couvrance Compacto Arena 10gr       Avene
#
#                                        short_description    analytic_category  \
# 6439   <p><strong>Avene Couvrance Compacto: </strong>...                  NaN
# 11091  <p>Maquillaje compacto en crema para pieles se...  Cosmética y Belleza
#
#                                                  picture
# 6439   https://www.mifarma.es/media/catalog/product/a...
# 11091  https://www.mifarma.es/media/catalog/product/a...

# %% [markdown]
# # OJO. Hay unos SKU repetidos - Qué hacemos?
# ## Ver que los cambios sean iguales en los otros df

# %%
sum(products["sku"].value_counts() > 1) & sum(products["product_id"].value_counts() > 1)
# Out:
# 0

# %%
products[products["product_id"] == 2493]
# Out:
#       product_id     sku                                 name marca_value  \
# 2191        2493  152792  Crema Reafirmante Woman Isdin 150ml       Isdin
#
#                                       short_description analytic_category  \
# 2191  <p>Esta crema está especialmente indicada para...          Infantil
#
#                                                 picture
# 2191  https://www.mifarma.es/media/catalog/product/2...

# %% [markdown]
# ### pictures

# %%
products["picture"].isna().sum()
# Out:
# 6

# %%
products["picture"].head(6)
# Out:
# 0    https://www.mifarma.es/media/catalog/product/1...
# 1    https://www.mifarma.es/media/catalog/product/1...
# 2    https://www.mifarma.es/media/catalog/product/2...
# 3    https://www.mifarma.es/media/catalog/product/1...
# 4    https://www.mifarma.es/media/catalog/product/0...
# 5    https://www.mifarma.es/media/catalog/product/0...
# Name: picture, dtype: object

# %%
products["picture"].value_counts()[:5]
# Out:
# https://www.mifarma.es/media/catalog/productno_selection               3
# https://www.mifarma.es/media/catalog/product/1/6/165774_.jpg           1
# https://www.mifarma.es/media/catalog/product/2/4/245100_391342_.jpg    1
# https://www.mifarma.es/media/catalog/product/1/5/152497_.jpg           1
# https://www.mifarma.es/media/catalog/product/8/0/80304935_.jpg         1
# Name: picture, dtype: int64

# %%
products[products["picture"] == "https://www.mifarma.es/media/catalog/productno_selection"]
# Los registros son diferentes. En este caso no sirve esta variable.
# Out:
#        product_id     sku                                     name  \
# 15519        4464  157259              Pro-Digest 2,6g 20 Capsulas
# 20402       27765  154583  PHB Classic Sensible Cepillo de Dientes
# 24992       22169  195156                      Epil-Off 3 Ampollas
#
#             marca_value                                  short_description  \
# 15519  Nutricion Center  <p>Pro-Digest es un complemento alimenticio na...
# 20402               PHB                      <p>PHB Classic Sensible\n</p>
# 24992      Otras Marcas  <p>Reduce y combaten la aparición del vello en...
#
#       analytic_category                                            picture
# 15519        Herbolario  https://www.mifarma.es/media/catalog/productno...
# 20402           Higiene  https://www.mifarma.es/media/catalog/productno...
# 24992               NaN  https://www.mifarma.es/media/catalog/productno...

# %%
pictures_sep = products["picture"].str.split("/", expand=True)

# %%
pictures_sep[6].value_counts()[:3]
# Out:
# 1    10252
# 3     1846
# 2     1376
# Name: 6, dtype: int64

# %%
pictures_sep[pictures_sep[6].isna()].head()
#Estos no tienen imag
# Out:
#             0    1               2      3        4                    5     6  \
# 3154      NaN  NaN             NaN    NaN      NaN                  NaN   NaN
# 3720      NaN  NaN             NaN    NaN      NaN                  NaN   NaN
# 12870     NaN  NaN             NaN    NaN      NaN                  NaN   NaN
# 15519  https:       www.mifarma.es  media  catalog  productno_selection  None
# 16328     NaN  NaN             NaN    NaN      NaN                  NaN   NaN
#
#           7     8
# 3154    NaN   NaN
# 3720    NaN   NaN
# 12870   NaN   NaN
# 15519  None  None
# 16328   NaN   NaN

# %%
pictures_sep[7].value_counts()[:3]
# Out:
# 7    3058
# 6    2943
# 5    2602
# Name: 7, dtype: int64

# %%
pic_con_split = products.join(pictures_sep)

# %%
pic_con_split.head()
# Out:
#    product_id     sku                                             name  \
# 0        7349  165774   Pañales CHELINO LOVE Talla3 4-10 KG 36unidades
# 1        7347  165776  Pañales CHELINO LOVE Talla5 13-18 KG 30unidades
# 2       50282  230154                     Pañales Pingo Maxi T4 40 uds
# 3        7348  165775   Pañales CHELINO LOVE Talla4 9-15 KG 34unidades
# 4       24517  011905                     Dodot Pañal T4 9-15Kg 30unds
#
#   marca_value                                  short_description  \
# 0     Chelino  <p>Los pañales <strong>Chelino</strong>, que p...
# 1     Chelino  <p>Los pañales Chelino que presentan un novedo...
# 2       Pingo  <p>Pingo es el primer pañal ecológico con cuat...
# 3     Chelino  <p>Los pañales Chelino, que presentan un noved...
# 4       Dodot  <p>¿Qué le pides a un pañal? ¿Absorción máxima...
#
#   analytic_category                                            picture  \
# 0          Infantil  https://www.mifarma.es/media/catalog/product/1...
# ...

# %%
pic_con_split[pic_con_split[6]== "1"].head()
# Out:
#     product_id     sku                                               name  \
# 0         7349  165774     Pañales CHELINO LOVE Talla3 4-10 KG 36unidades
# 1         7347  165776    Pañales CHELINO LOVE Talla5 13-18 KG 30unidades
# 3         7348  165775     Pañales CHELINO LOVE Talla4 9-15 KG 34unidades
# 7        60743  183816  Cumlaude Sunlaude Niños Ultrafluido Mineral SP...
# 10       75634  160842  FreeLife by Bebe Cash 50 Pañales Talla 4 (7-18kg)
#
#               marca_value                                  short_description  \
# 0                 Chelino  <p>Los pañales <strong>Chelino</strong>, que p...
# 1                 Chelino  <p>Los pañales Chelino que presentan un novedo...
# 3                 Chelino  <p>Los pañales Chelino, que presentan un noved...
# 7                Rilastil  <p>Muy alta protección solar formulada con <st...
# 10  Freelife by bebe cash  <p>Pañales especialmente diseñados para niños ...
#
# ...

# %%
#Algo pueden decir los números de las columnas 6 y 7... Pero por lo visto NO se refiere a las categorías.

# %% [markdown]
# ### Short description

# %%
description_sep = products["short_description"].str.split("<strong>", expand=True)

# %%
description_sep[description_sep[2].notna()].head()
# Out:
#                                                0  \
# 0                                <p>Los pañales
# 7    <p>Muy alta protección solar formulada con
# 71                                           <p>
# 79               <p>Gel limpiador indicado para
# 117                   <p>Blemil Plus 1 Forte es
#
#                                                      1  \
# 0    Chelino</strong>, que presentan un novedoso di...
# 7              filtros físicos</strong> indicada para
# 71   Mussvital Loción Hidratante</strong> es una fó...
# 79   pieles grasas o mixtas y con acné juvenil.</st...
# 117  leche para lactantes</strong> indicada para sa...
#
#                                                      2     3     4     5     6
# 0                           36unidades.</strong>\n</p>  None  None  None  None
# 7    bebés desde el primer día y niños/as</strong>....  None  None  None  None
# 71                       Sin parabenos</strong>.\n</p>  None  None  None  None
# ...

# %%
import re

# %%
products["short_description"] = products["short_description"].str.replace(r'<[^<]+?>', '', regex=True)

# %%
products["short_description"].head()
# Out:
# 0    Los pañales Chelino, que presentan un novedoso...
# 1    Los pañales Chelino que presentan un novedoso ...
# 2    Pingo es el primer pañal ecológico con cuatro ...
# 3    Los pañales Chelino, que presentan un novedoso...
# 4    ¿Qué le pides a un pañal? ¿Absorción máxima, q...
# Name: short_description, dtype: object

# %% [markdown]
# ### names

# %%
descript_con_split = products.join(description_sep)

# %%
products["name"].isna().sum() #Ya no hay missings en names!
# Out:
# 0

# %%
descript_con_split.shape
# Out:
# (23183, 14)

# %%
products.shape
# Out:
# (23183, 7)

# %%
products[products.duplicated(["name"], keep=False)].head()
# Out:
#       product_id     sku                                               name  \
# 1392       15433  163575                               Listerine Zero 500ml
# 1454       27786  175341  Singuladerm XpertSun Perfection Natural SPF 50 5g
# 3323       49144  370406        Sesderma Hidraloe Crema Contorno Ojos 15 ml
# 4359        4289  167926               Bioderma Atoderm Gel Moussant 500 ml
# 5405       47521   70407       Solgar Vitamina C 500 mg 90 comp masticables
#
#       marca_value                                  short_description  \
# 1392    Listerine           Enjuague bucal más suave y sin alcohol\n
# 1454  Singuladerm  Fotoprotector mineral SPF30 en formato polvo, ...
# 3323     Sesderma  Tu mirada más rejuvenecida e iluminada gracias...
# 4359     Bioderma  Gel limpiador diario reengrasante purificante ...
# 5405       Solgar  Vitamina C masticable con sabor naranja. Ayuda...
#
#         analytic_category                                            picture
# ...

# %%
names_sep = products["name"].str.split(" ", expand=True)

# %%
names_sep.tail(10)
# Out:
#                0           1         2           3               4        5   \
# 27931  Exfoliante  Supernoche    Atashi        75ml            None     None
# 27933        Soja       Verde   (Mungo)         Bio         Ecosana    500gr
# 27935        Trío      Sombra        de        Ojos  Hipoalergénica     HYPO
# 27939       Crema          de      Cara      Pieles       Delicadas        y
# 27941      Pinzas          de   Depilar  Magnéticas           Punta  Oblicua
# 27942       Grisi        Pack     Cesta        Aloe            Vera     None
# 27943      Broche    Cadenita        de     Chupete             MAM     Clip
# 27944      Espejo     Mifarma    Animal       Print            None     None
# 27950   Corrector     Líquido   Sublime   Ecológico         PuroBio     Tono
# 27952    Plantoys      Cocina  Infantil          de          Madera     None
#
#                 6         7      8     9   ...    34    35    36    37    38  \
# ...

# %%
nombre_corto = names_sep[0].astype(str) + " " + names_sep[1].astype(str) + " " + names_sep[2].astype(str) + " " + names_sep[3].astype(str) + " " + names_sep[4].astype(str)

# %%
nombre_corto.tail(10)
# Out:
# 27931         Exfoliante Supernoche Atashi 75ml None
# 27933                 Soja Verde (Mungo) Bio Ecosana
# 27935             Trío Sombra de Ojos Hipoalergénica
# 27939                 Crema de Cara Pieles Delicadas
# 27941             Pinzas de Depilar Magnéticas Punta
# 27942                     Grisi Pack Cesta Aloe Vera
# 27943                 Broche Cadenita de Chupete MAM
# 27944               Espejo Mifarma Animal Print None
# 27950    Corrector Líquido Sublime Ecológico PuroBio
# 27952             Plantoys Cocina Infantil de Madera
# dtype: object

# %%
nombre_corto = nombre_corto.str.replace(" None", "")

# %%
nombre_corto = nombre_corto.str.title()

# %%
nombre_corto.rename("nombre corto");

# %%
nombre_corto = nombre_corto.to_frame().rename(columns= {0: "nombre_corto"})

# %%
#Aquí creamos una nueva columna con los nombres cortos( solo las 5 primeras palabras)
products = products.join(nombre_corto)

# %%
products.head()
# Out:
#    product_id     sku                                             name  \
# 0        7349  165774   Pañales CHELINO LOVE Talla3 4-10 KG 36unidades
# 1        7347  165776  Pañales CHELINO LOVE Talla5 13-18 KG 30unidades
# 2       50282  230154                     Pañales Pingo Maxi T4 40 uds
# 3        7348  165775   Pañales CHELINO LOVE Talla4 9-15 KG 34unidades
# 4       24517  011905                     Dodot Pañal T4 9-15Kg 30unds
#
#   marca_value                                  short_description  \
# 0     Chelino  Los pañales Chelino, que presentan un novedoso...
# 1     Chelino  Los pañales Chelino que presentan un novedoso ...
# 2       Pingo  Pingo es el primer pañal ecológico con cuatro ...
# 3     Chelino  Los pañales Chelino, que presentan un novedoso...
# 4       Dodot  ¿Qué le pides a un pañal? ¿Absorción máxima, q...
#
#   analytic_category                                            picture  \
# 0          Infantil  https://www.mifarma.es/media/catalog/product/1...
# ...

# %% [markdown]
# # Ojo! Nombres repetidos... Esto podría ser lo mismo, sin embargo contrastar con los otros df.
#
# ## Los sku tienen diferencias sutiles. Se podrían eliminar duplicados después de hacer limpieza de sku...

# %% [markdown]
# ### marca

# %%
products["marca_value"] = products["marca_value"].str.lower()

# %%
products["marca_value"].head()
# Out:
# 0    chelino
# 1    chelino
# 2      pingo
# 3    chelino
# 4      dodot
# Name: marca_value, dtype: object

# %%
products["marca_value"].isna().sum()
# Out:
# 29

# %%
descript_con_split[descript_con_split["marca_value"].isna()].head()
# Out:
#       product_id                         sku  \
# 622         9467                      162269
# 923         7105                      157899
# 1029        1031  SERV262253X2-262253-262253
# 4376        7108                      152810
# 4451         513      317171x2-317171-317171
#
#                                                    name marca_value  \
# 622                               Prelox 60 Comprimidos         NaN
# 923                      Dr Dunner Cinnulin 40 Capsulas         NaN
# 1029  Interapothek Champu Anticaida 400 ml + 400 ml ...         NaN
# 4376                      Dr Dunner Menosoy 60 Capsulas         NaN
# 4451  La Roche Posay Solucion Micelar 200ml + 200 ml...         NaN
#
#                                       short_description analytic_category  \
# 622               Ayuda contra la disfunción erectil.\n       Vida Íntima
# 923   Cuida tus niveles de azúcar: Complemento alime...        Herbolario
# ...

# %%
products["marca_value"][622] = "prelox"
# Out:
# /tmp/ipykernel_269695/4007907723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["marca_value"][622] = "prelox"

# %%
products["marca_value"][923] = "dr. dunner"
products["marca_value"][1029] = "interapothek"
# Out:
# /tmp/ipykernel_269695/2740116173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["marca_value"][923] = "dr. dunner"
# /tmp/ipykernel_269695/2740116173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["marca_value"][1029] = "interapothek"

# %%
products["marca_value"][4376] = "dr. dunner"
products["marca_value"][4451] = "la roche posay"
products["marca_value"][5063] = "medela"
products["marca_value"][5738] = "dr. dunner"
products["marca_value"][5863] = "dr. dunner"
products["marca_value"][5939] = "dr. dunner"
products["marca_value"][7308] = "medela"
products["marca_value"][9188] = "dr. dunner"
products["marca_value"][9820] = "medela"
products["marca_value"][9188] = "dr. dunner"
products["marca_value"][9992] = "medela"
products["marca_value"][10281] = "medela"
products["marca_value"][11338] = "dr. dunner"
products["marca_value"][11680] = "dr. dunner"
products["marca_value"][12641] = "dr. dunner"
products["marca_value"][14110] = "lierac"
products["marca_value"][16104] = "medela"
products["marca_value"][16774] = "mi rebotica"
products["marca_value"][17680] = "mi rebotica"
products["marca_value"][18124] = "dr. dunner"
products["marca_value"][19842] = "medela"
products["marca_value"][20447] = "medela"
products["marca_value"][21037] = "dr. dunner"
products["marca_value"][24622] = "dr. dunner"
products["marca_value"][13094] = "rene furterer"
# Out:
# /tmp/ipykernel_269695/2746017985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["marca_value"][4376] = "dr. dunner"
# /tmp/ipykernel_269695/2746017985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["marca_value"][4451] = "la roche posay"
# /tmp/ipykernel_269695/2746017985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["marca_value"][5063] = "medela"
# ...

# %%
products[products["marca_value"] == "rene furterer"].head()
# Out:
#       product_id          sku  \
# 211         8704       239442
# 258         8650       150710
# 605         8642       151105
# 966        46294  150712duplo
# 1006        8705       239434
#
#                                                    name    marca_value  \
# 211        RENE furterer triphasic vht+ 8 frascos 5,5ml  rene furterer
# 258      RENE furterer okara champu activador luz 200ml  rene furterer
# 605              RENE furterer naturia champu seco 75ml  rene furterer
# 966   RENE Furterer Initia Champu Volumen Vitalidad ...  rene furterer
# 1006  RENE furterer rf 80 tratamiento anticaida 12 a...  rene furterer
#
#                                       short_description    analytic_category  \
# 211   Triphasic VHT contrarresta la caída del cabell...  Cosmética y Belleza
# 258   Champú activador de luz indicado para lucir un...  Cosmética y Belleza
# 605   Champú en seco que absorbe la grasa y las impu...  Cosmética y Belleza
# ...

# %%
products[products["marca_value"].isna()]
# Out:
#        product_id     sku                                          name  \
# 16276        5664  160250                              Flammaspray 75ml
# 26700       96969  190406  Loción Capilar Anticaída Forte Farline 100ml
#
#       marca_value                                  short_description  \
# 16276         NaN                               Quemaduras del Sol\n
# 26700         NaN  Loción capilar anticaída concentrada indicada ...
#
#          analytic_category                                            picture  \
# 16276  Cosmética y Belleza  https://www.mifarma.es/media/catalog/product/1...
# 26700  Cosmética y Belleza  https://www.mifarma.es/media/catalog/product/1...
#
#                                  nombre_corto
# 16276                        Flammaspray 75Ml
# 26700  Loción Capilar Anticaída Forte Farline

# %% [markdown]
# ## Quedan dos nulos en marca. A ver qué se puede hacer con ellos

# %%
products[products["marca_value"] == "interapothek"].head()
# Out:
#      product_id     sku                                      name  \
# 132       10090  375642         ia Bastoncillos de Seguridad 50ud
# 198         898  156864         Interapothek Solucion Unica 500ml
# 318         956  328230       Interapothek Esponja Natural Grande
# 580        9506  165981           Interapothek Agua de Mar 100 ml
# 784       28095  482307  Interapothek Compresas Gasa Esteril c/50
#
#       marca_value                                  short_description  \
# 132  interapothek  Bastoncillos de algodón hidrófilo para la higi...
# 198  interapothek                Interapothek Solucion Unica 500ml\n
# 318  interapothek  La esponja natural de Interapothek limpia con ...
# 580  interapothek                                      Agua de mar\n
# 784  interapothek  50 gasas esteriles para limpiar cualquier clas...
#
#     analytic_category                                            picture  \
# 132          Infantil  https://www.mifarma.es/media/catalog/product/3...
# ...

# %% [markdown]
# ### category

# %%
products["analytic_category"].value_counts()
# Out:
# Cosmética y Belleza    6821
# Higiene                4334
# Infantil               3857
# Herbolario             2487
# Nutrición              1461
# Ortopedia               496
# Vida Íntima             259
# Óptica                  195
# Perfumeria              145
# Veterinaria              45
# Name: analytic_category, dtype: int64

# %%
products["analytic_category"].unique()
# Out:
# array(['Infantil', nan, 'Cosmética y Belleza', 'Óptica', 'Higiene',
#        'Herbolario', 'Ortopedia', 'Nutrición', 'Vida Íntima',
#        'Veterinaria', 'Perfumeria'], dtype=object)

# %%
products["analytic_category"].isna().sum()
# Out:
# 3083

# %%
# Las categorías se pueden tomar del otro df

# %%
products[products["analytic_category"].isna()].head()
# Out:
#     product_id     sku                                               name  \
# 4        24517  011905                       Dodot Pañal T4 9-15Kg 30unds
# 5        11938  011896         Dodot Activity T3 De 4 A 10 Kg 56 Unidades
# 6        13109  011894              Dodot Pañal Sensitive T1 2-5Kg 30Unds
# 14       12051  013687  Dodot Sensitive Pañal Primeras Semanas T/0 Has...
# 31       13122  011907          Dodot Pañal Pack Semanal T/5 13-18kg 25ud
#
#    marca_value                                  short_description  \
# 4        dodot  ¿Qué le pides a un pañal? ¿Absorción máxima, q...
# 5        dodot  Pañales que mantienen la piel del culito seca ...
# 6        dodot  Pañales para recién nacido que evitan la irrit...
# 14       dodot  Pañales Dodot para una máxima absorción de pip...
# 31       dodot                             Pañales pack semanal\n
#
#    analytic_category                                            picture  \
# ...

# %% [markdown]
# #### product_id - sku
# Varios duplicados. El número es diferente al de sku duplicados.
# product_id conecta con órdenes. Importante verificar que hacen match.
#
# #### sku
# IMPORTANTE. El sku nos va a permitir integrar con dataset de categorías.
#
#
# #### category
# Hay 3537 nulos... Tomar del otro dataset y corregir. Cubrimos las categorías primarias... Se podría tirar un modelo con palabras para obtener categorías secundarias? Quizás no sea necesario. Pensar...

# %%
products.head()
# Out:
#    product_id     sku                                             name  \
# 0        7349  165774   Pañales CHELINO LOVE Talla3 4-10 KG 36unidades
# 1        7347  165776  Pañales CHELINO LOVE Talla5 13-18 KG 30unidades
# 2       50282  230154                     Pañales Pingo Maxi T4 40 uds
# 3        7348  165775   Pañales CHELINO LOVE Talla4 9-15 KG 34unidades
# 4       24517  011905                     Dodot Pañal T4 9-15Kg 30unds
#
#   marca_value                                  short_description  \
# 0     chelino  Los pañales Chelino, que presentan un novedoso...
# 1     chelino  Los pañales Chelino que presentan un novedoso ...
# 2       pingo  Pingo es el primer pañal ecológico con cuatro ...
# 3     chelino  Los pañales Chelino, que presentan un novedoso...
# 4       dodot  ¿Qué le pides a un pañal? ¿Absorción máxima, q...
#
#   analytic_category                                            picture  \
# 0          Infantil  https://www.mifarma.es/media/catalog/product/1...
# ...

# %%
#Guardo documento:
products.to_csv("products_limpieza1.csv")
